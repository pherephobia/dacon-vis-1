# %% [markdown]
# <center>
#     <img src="https://news.kbs.co.kr/data/news/2018/12/26/4102880_1x1.jpg" alt="centered image" />
# </center>

# %% [markdown]
# # 배경 및 목적
#
# 현대 민주주의는 대의 민주주의(representative democracy)이며, 그 중심에는 유권자에 의해 선출되어 위임받은 권한을 행사하는 대표자(representatives)가 존재합니다. 한정된 자원과 시간 등의 문제로 직접 민주주의가 불가능한 지금, 대의 민주주의는 현실적으로 선택가능한 제도라고 할 수 있습니다. 그렇다면 우리의 고민은 우리사회의 대의 민주주의가 실현되는 공간, 국회가 과연 유권자들의 기대에 부응하고 있는지, 혹은 과거에는 부족했을지라도 점차 나아지고 있는지, 그러한 변화가 실질적인 것인지 표면적인 것에 불과하는지를 이해하는 것입니다.
#
# 국회의 입법활동은 이러한 대의 민주주의의 작동원리와 성과를 직접적으로 보여주는 정치적 행위입니다. 그럼에도 불구하고 국회의 입법활동은 전문적인 용어들과 법률 조항, 제도들로 인하여 일반 시민들이 쉽게 접근하기 어려운 영역에 머물러 있습니다. 우리 국회는 국회 내 회의들의 속기록 및 의사결정 사항들을 다양한 방식으로 중계하고 공개하여 그 투명성을 날로 제고하고 있지만, 정작 입법 과정을 이해하고 실생활과 연관 지어 생각하는 것은 쉽지 않습니다.

# %% [markdown]
# ## 시각화를 위한 질문들
#
# 이 프로젝트를 통해 우리는 다음과 같은 질문들을 시각화를 통해 보다 직관적인 방식으로 접근해보고자 합니다.
#
# ### 1. 각 대수 국회 입활활동 평가
#
# > 15대 이후 각 대수의 국회에서 회기 기간 동안 얼마나 입법활동을 활발히 하였는가? 활동 정도의 변화가 있었는가?
#
# > 법안처리결과 (폐기, 가결, 대안반영)는 어떻게 나타나는지?
#
# 국회의 입안 수는 일반적으로 입법생산성을 보여주는 지표로 평가됩니다. 하지만 높은 생산성이 있는, 높은 성과를 내는 의원이라고 실적을 평가받고자 하는 국회의원들은 법리적으로 충분히 검토되지 않은 법안들을 일괄적으로 제출할 수도 있습니다. 따라서 법안처리결과에 대한 자료를 함께 보여줌으로써 실질적인 입법활동의 생산성을 살펴보고자 합니다.

# %% [markdown]
# ### 2. 국회의원 입법활동의 공익 목적의 부합성
#
# > 국회의원들이 발의하는 안건이 지역적으로 편중된 예산지원이 가능한 사업 (e.g. 쪽지예산 사업)에 편중되는지 아니면 공익적 (전국적) 사업에도 골고루 나타나는가?
#
# > 과연 초당적 발의 (소속 정당에 무관하게 나타나는 공동발의)가 어떠한 분야의 입법활동에서 활발하게 나타나는지?
#
#
# 국회의원들은 임기 중 국민을 대표하는 공인입니다. 따라서 국회의원의 입법활동이 과연 공익적 목적에 부합하는가에 대해 살펴보는 것은 중요하며, 동시에 국회의 입법활동의 정당성에 영향을 미칠 수 있습니다.

# %% [markdown]
# ### 3. 초선의원의 입법활동의 차별성
#
# > 초선의원의 입법활동은 재/다선의원의 입법활동과 차별점이 있는가?
#
# 국회의원은 매 회기별로 선거를 통해 새롭게 선출됩니다. 이 과정을 통해 특정 정책적 선호를 가진 국회의원은 재선을 통해 자신의 이해를 입법활동을 통해 지속적으로 반영할 수 있습니다. 한편으로, 초선의원이라는 새로운 이해관계를 가진 행위자의 충원을 통해 이전 회기의 국회에서 충분히 대표되지 않았던 분야의 이익이 새롭게 대표될 수 있습니다. 따라서 초선의원의 입법활동의 특징은 어떠한가에 대해 살펴볼 필요가 있습니다.

# %% [markdown]
# ### 4. 각 국회의 주요 핵심사안
#
# > 15대부터 각 국회의 주요 핵심 키워드 (관심 입법안)가 무엇이었고, 그것이 당시의 국정기조/사회현황을 잘 반영하였는지?

# %% [markdown]
# 위의 질문들을 시각화하면서 우리는 국민의 대표가 과연 열심히 일을 하고 있는지, 제대로 일을 하고 있는지, 충분히 변화하는 사회에 맞추어 입법활동을 개선하고 있는지, 당파적 이해를 떠난 공익적 입법활동을 하고 있는지에 대한 기초적인 답변을 할 수 있을 것으로 기대합니다.

# %%
# install.packages("showtext", repos='http://cran.us.r-project.org')

# %%
options(scipen = 999, warn=-1)
suppressMessages(library(tidyverse))
suppressMessages(library(ggthemes))
suppressMessages(library(showtext))
font_add_google('Noto Sans KR', 'notosanskr')
font_add_google('Nanum Pen Script', 'nanumpen')
showtext_auto()

# %%
# 데이터 로딩
people_data <- read.csv("data/new_people.csv")
suggest_data <- read.csv("data/suggest.csv")
process_data <- read.csv("data/process.csv")

# %%
people_info <- people_data %>%
    select(DAESU:BIRTH) %>%
    filter(DAESU >= 15)
head(people_info)
# Out:
#   DAESU
# 1 21
# 2 21
# 3 21
# 4 21
# 5 21
# 6 21
#   DAE
# 1 제19대국회의원(경남 창원시성산구) 정당_66\n제21대국회의원(경남 창원시성산구) 정당_74
# 2 제21대국회의원(대구동구을) 정당_74
# 3 제21대국회의원(경기안양시만안구) 정당_7
# 4 제21대국회의원(경남진주시을) 정당_74
# 5 제21대국회의원(비례대표) 정당_30
# 6 제20대국회의원(서울 은평구을) 정당_7\n제21대국회의원(서울 은평구을) 정당_7\n
#   DAE_NM   NAME   NAME_HAN JA HO BIRTH
# 1 21대의원 강기윤 姜起潤         1960년 06월 04일
# 2 21대의원 강대식 姜大植         1959년 11월 02일
# 3 21대의원 강득구 姜得求         1963년 05월 27일
# 4 21대의원 강민국 姜旻局         1971년 03월 03일
# 5 21대의원 강민정 姜旼姃         1961년 04월 26일
# 6 21대의원 강병원 姜炳遠         1971년 07월 09일

# %%
# options(repr.plot.width = 3, repr.plot.height = 2, repr.plot.res = 300)
options(repr.plot.width=8, repr.plot.height=5)
people_info %>%
    mutate(DAESU = paste(DAESU, "대")) %>%
    group_by(DAESU) %>%
    summarize(n = n()) %>%
    ggplot(., aes(x = as.factor(DAESU), n)) +
    geom_bar(stat = "identity", col = "gray10", width = 0.75, fill = "orangered3") +
    geom_text(aes(y = n + 15, label = n), size = 12, family="notosanskr")+
    theme_fivethirtyeight() +
    ylim(NA, 400) + 
    theme(legend.position = "none",
          panel.grid.major.x=element_blank(),
          title = element_text(size = 50, family="notosanskr"),
          axis.title = element_text(size = 30, family="notosanskr"), 
          axis.text = element_text(size = 30, family="notosanskr"), 
          axis.line = element_line(size = 0.4, colour = "grey10")) +
    labs(title = "국회 대수별 국회의원 수",
         x = "", y = "인원 수 (명)")
# Out:
# plot without title
